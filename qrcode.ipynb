# %%
pip install PyQRCode
# Out:
# ...
#   Created wheel for PyQRCode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36247 sha256=658eb66e3325f99dce7d9e2e8d4182b3e6be3403c54f2fd7ffcbe740c5ef724f
#   Stored in directory: c:\users\erhan\appdata\local\pip\cache\wheels\da\75\c0\38c7f82750de2725429b6b8571dca254249d73f6c882c5d9b1
# Successfully built PyQRCode
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyqrcode

url = pyqrcode.create('https://puhutv.com/behzat-c-53-bolum-izle')
url.svg('uca-url.svg', scale=8)
url.eps('uca-url.eps', scale=2)
print(url.terminal(quiet_zone=1))
